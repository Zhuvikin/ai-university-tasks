# %%
import numpy as np

randomNumbers = np.random.randint(0, 101, size=100);

print(randomNumbers)
# Out:
# [ 76  64  82  94  27  79  61  96  43   1  92  85  53  38  38  21  20  54
#  100  45  91  23   6  88  64  76  95  34   0  76  46  38  37  35  98  37
#   54  77  70  27  37  83  56  74  16  10  69  11  83  16  22  40  63  68
#   61  33  47  98  37  38   9  53   9  69  87  86  98  17  33  47  34  77
#   56  15  76  67  41   1  54  48  18  62  14   2   8  24  11  26  81  32
#   15  24  89  91  99  92  14  24  63  33]

# %%
import matplotlib.pyplot as plt

plt.plot(randomNumbers)
plt.show()

# %%
# Python program for implementation of Bubble Sort
def bubbleSort(arr):
    n = len(arr)
 
    # Traverse through all array elements
    for i in range(n):
 
        # Last i elements are already in place
        for j in range(0, n-i-1):
 
            # traverse the array from 0 to n-i-1
            # Swap if the element found is greater
            # than the next element
            if arr[j] > arr[j+1] :
                arr[j], arr[j+1] = arr[j+1], arr[j]
 
# Driver code to test above 
bubbleSort(randomNumbers)

print(randomNumbers)

plt.plot(randomNumbers)
plt.show()
# Out:
# [  0   1   1   2   6   8   9   9  10  11  11  14  14  15  15  16  16  17
#   18  20  21  22  23  24  24  24  26  27  27  32  33  33  33  34  34  35
#   37  37  37  37  38  38  38  38  40  41  43  45  46  47  47  48  53  53
#   54  54  54  56  56  61  61  62  63  63  64  64  67  68  69  69  70  74
#   76  76  76  76  77  77  79  81  82  83  83  85  86  87  88  89  91  91
#   92  92  94  95  96  98  98  98  99 100]

# %%
x = np.arange(0, 100, 1)
y = np.random.randint(0, 101, 100)

fig, ax = plt.subplots()
ax.plot(x, y)

ax.set(xlabel='element num', ylabel='array values', title='Unsorted initial array')
ax.grid()
plt.show()

# %%
ysorted = np.sort(y)
fig, ax = plt.subplots()
ax.plot(x, ysorted)

ax.set(xlabel='element num', ylabel='array values', title='Sorted initial array')
ax.grid()
plt.show()
